# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Importing the datase
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")

# 1. Display First 5 Rows of The Dataset

dataset.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
# 2. Check Last 5 Rows of The Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")



dataset.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
#3.Find Shape of Our Dataset (Number of Rows And Number of Columns)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")

dataset.shape
# Out:
# (1000, 12)

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")


dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#5. Check Null Values In The Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")

dataset.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")
# 6. We can also see the number of unique users and items in the dataset.
dataset.nunique()
# Out:
# Rank                  1000
# Title                  999
# Genre                  207
# Description           1000
# Director               644
# Actors                 996
# Year                    11
# Runtime (Minutes)       94
# Rating                  55
# Votes                  997
# Revenue (Millions)     814
# Metascore               84
# dtype: int64

# %%
#7. Drop All The Missing Values
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")
dataset = dataset.dropna(axis=0)

# %%
#8. Check For Duplicate Data

dup_data=dataset.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %%
#9. Get Overall Statistics About The DataFrame

dataset.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
#10. Display Title of The Movie Having Runtime >= 180 Minutes

dataset[dataset['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %%
#11. In Which Year There Was The Highest Voting?

sns.barplot(x='Year',y='Votes',data=dataset)
plt.title("Votes By Year")
plt.show()

# %%
#12. In Which Year There Was The Highest Revenue?

sns.barplot(x='Year',y='Revenue (Millions)',data=dataset)
plt.title("Revenue By Year")
plt.show()

# %%
#13. Find The Average Rating For Each Director

dataset.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %%
#14. Display Number of Movies Per Year

sns.countplot(x='Year',data=dataset)
plt.title("Number of Movies Per Year")
# Out:
# Text(0.5, 1.0, 'Number of Movies Per Year')

# %%
#15. Find Most Popular Movie Title (Higest Revenue)

dataset.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
dataset[dataset['Revenue (Millions)'].max() == dataset['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
# 16. Find Top 10 Movies by Revenue

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
top_10=dataset.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)','Director']].set_index('Title')

# Plotting using seaborn

plt.figure(figsize=(10, 6))
sns.barplot(x=top_10.index, y='Revenue (Millions)', data=top_10)
plt.title('Top 10 Movies by Revenue (Millions)')
plt.xlabel('Movie Title')
plt.ylabel('Revenue (Millions)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#17. Display Top 10 Highest Rated Movie Titles And its Directors

top_10=dataset.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')

# %%
#18. Display Top 10 Highest Revenue Movie Titles

dataset.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_10
# Out:
#                        Rating                          Director
# Title
# The Dark Knight           9.0                 Christopher Nolan
# Inception                 8.8                 Christopher Nolan
# Interstellar              8.6                 Christopher Nolan
# Kimi no na wa             8.6                    Makoto Shinkai
# The Intouchables          8.6                   Olivier Nakache
# The Prestige              8.5                 Christopher Nolan
# The Departed              8.5                   Martin Scorsese
# The Dark Knight Rises     8.5                 Christopher Nolan
# Whiplash                  8.5                   Damien Chazelle
# The Lives of Others       8.5  Florian Henckel von Donnersmarck

# %%
# 19.Display Top 10 Movies by Rating

top_10=dataset.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')

# Plotting using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10.index, y='Rating', data=top_10)
plt.title('Top 10 Movies by Rating')
plt.xlabel('Movie Title')
plt.ylabel('Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#20 Movies by Revenue (Millions)

dataset.sort_values(by='Revenue (Millions)',ascending=False).head(10)
# Out:
#      Rank                                       Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 87     88                                      Avatar
# 85     86                              Jurassic World
# 76     77                                The Avengers
# 54     55                             The Dark Knight
# 12     13                                   Rogue One
# 119   120                                Finding Dory
# 94     95                     Avengers: Age of Ultron
# 124   125                       The Dark Knight Rises
# 578   579             The Hunger Games: Catching Fire
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 87     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 76                Action,Sci-Fi
# 54           Action,Crime,Drama
# 12      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 94      Action,Adventure,Sci-Fi
# 124             Action,Thriller
# 578    Action,Adventure,Mystery
#
# ...

# %%
#21. Find Average Rating of Movies Year-wise
dataset.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# 22. Average Rating of Movies Year-wise
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame containing movie data

data1 = dataset.groupby('Year')[['Rating']].mean().sort_values(by='Rating', ascending=False)

# Plotting using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x=data1.index, y='Rating', data=data1, palette='viridis')
plt.title('Average Rating of Movies Year-wise')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\beaut\AppData\Local\Temp\ipykernel_11252\2610408966.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data1.index, y='Rating', data=data1, palette='viridis')

# %%
#23. Does Rating Affect The Revenue?  Ans=yes

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=dataset)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
#24. Display Top 10 Lengthy Movies Title

le =dataset.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')

# Plotting
le.plot(kind='bar', figsize=(10, 6))
plt.title('Top 10 Lengthy Movies')
plt.xlabel('Movie Title')
plt.ylabel('Runtime (Minutes)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#25. Count Number of Action Movies

list1=[]
for value in dataset['Genre']:
    list1.append(value.split(','))

dataset['temp']=list1

len(dataset[dataset['Genre'].str.contains('action',case=False)])
# Out:
# 303

# %%
#26. # Display the top 10 Director name based on revenue

import pandas as pd

# Read the dataset
dataset = pd.read_csv(r"C:\Users\beaut\Desktop\projects\pythonProject\IMDB-Movie-Data.csv")

# Sort the dataset by revenue in descending order and select the top 5
top_10_revenue = dataset.nlargest(10, 'Revenue (Millions)')

# Display the top 10 Director name based on revenue
print(top_10_revenue[['Director','Revenue (Millions)']])
# Out:
#               Director  Revenue (Millions)
# 50         J.J. Abrams              936.63
# 87       James Cameron              760.51
# 85     Colin Trevorrow              652.18
# 76         Joss Whedon              623.28
# 54   Christopher Nolan              533.32
# 12      Gareth Edwards              532.17
# 119     Andrew Stanton              486.29
# 94         Joss Whedon              458.99
# 124  Christopher Nolan              448.13
# 578   Francis Lawrence              424.65
